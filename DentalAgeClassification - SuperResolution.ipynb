# %% [markdown]
# ### Classificação binária de idade utilizado radiografias panorâmicas da arcada dentária

# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
#import tensorflow_datasets as tfds

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import os
cwd = os.getcwd()

# Shows Current Working Directory
print(cwd)

print(tf.__version__)
# Out:
# C:\Users\lucas\Desktop\PDI - Git\PDI_Dental_Age_Classification
# 2.9.1

# %% [markdown]
# Dental22
#   22Under/
#   22OrOver/

# %%
import pathlib

data_dir = cwd + '/data'
data_dir = pathlib.Path(data_dir)
print(data_dir)
# Out:
# C:\Users\lucas\Desktop\PDI - Git\PDI_Dental_Age_Classification\data

# %% [markdown]
# Total de imagens:

# %%
image_count = len(list(data_dir.glob('*.jpg')))
print(image_count)
# Out:
# 73

# %% [markdown]
# Cada diretório contém imagens de pacientes abaixo de 22 anos ou de 22 anos acima.

# %%
under22 = list(data_dir.glob('22Under/*'))
PIL.Image.open(str(under22[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1581x720 at 0x18DEAFC44F0>

# %%
data_ds = cwd + '\\Training-Test-Super-Resolution-Data/'

# %%
aux_list = tf.data.Dataset.list_files(str(data_ds+'*/*'), shuffle=False)

# %%
for i in aux_list:
    print(i)
# Out:
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20200918150056444.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20200918150056444_0_8727.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20200918150056444_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20200918150056444_negative_0_7231.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20200918150056444_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20200918150056444_positive_0_4066.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20200918150056444zoom_in_0_1872.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20200918150056444zoom_in_0_1872_0_5131.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20200918150056444zoom_out_0_9579.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20200918150056444zoom_out_0_9579_0_5506.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201014090537993.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201014090537993_0_6373.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201014090537993_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201014090537993_negative_0_5932.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201014090537993_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201014090537993_positive_0_3755.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201014090537993zoom_in_0_7660.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201014090537993zoom_in_0_7660_0_4384.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201014090537993zoom_out_0_2889.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201014090537993zoom_out_0_2889_0_2496.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201016160206586.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201016160206586_0_5399.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201016160206586_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201016160206586_negative_0_185.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201016160206586_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201016160206586_positive_0_5970.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201016160206586zoom_in_0_6192.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201016160206586zoom_in_0_6192_0_4600.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201016160206586zoom_out_0_3454.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201016160206586zoom_out_0_3454_0_4772.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201127151603974.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201127151603974_0_3694.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201127151603974_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201127151603974_negative_0_4996.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201127151603974_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201127151603974_positive_0_4149.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201127151603974zoom_in_0_5409.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201127151603974zoom_in_0_5409_0_3127.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201127151603974zoom_out_0_4588.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201127151603974zoom_out_0_4588_0_7992.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201215150320498.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201215150320498_0_6337.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201215150320498_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201215150320498_negative_0_2488.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201215150320498_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201215150320498_positive_0_9393.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201215150320498zoom_in_0_2110.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201215150320498zoom_in_0_2110_0_2643.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201215150320498zoom_out_0_3984.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201215150320498zoom_out_0_3984_0_31.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201217150805586.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201217150805586_0_5330.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201217150805586_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201217150805586_negative_0_8803.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201217150805586_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201217150805586_positive_0_2428.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201217150805586zoom_in_0_7672.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201217150805586zoom_in_0_7672_0_173.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201217150805586zoom_out_0_6457.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201217150805586zoom_out_0_6457_0_8305.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20210108164409410.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20210108164409410_0_3549.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20210108164409410_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20210108164409410_negative_0_8606.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20210108164409410_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20210108164409410_positive_0_2531.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20210108164409410zoom_in_0_2143.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20210108164409410zoom_in_0_2143_0_2614.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20
positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220124142821672_positive_0_4965.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220124142821672zoom_in_0_2518.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220124142821672zoom_in_0_2518_0_7121.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220124142821672zoom_out_0_263.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220124142821672zoom_out_0_263_0_6953.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220128121500407.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220128121500407_0_8529.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220128121500407_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220128121500407_negative_0_7789.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220128121500407_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220128121500407_positive_0_7223.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220128121500407zoom_in_0_3380.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220128121500407zoom_in_0_3380_0_8565.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220128121500407zoom_out_0_4729.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220128121500407zoom_out_0_4729_0_3345.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220209164953264.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220209164953264_0_608.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220209164953264_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220209164953264_negative_0_1531.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220209164953264_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220209164953264_positive_0_3395.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220209164953264zoom_in_0_3335.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220209164953264zoom_in_0_3335_0_7489.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220209164953264zoom_out_0_9941.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220209164953264zoom_out_0_9941_0_3499.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220210150834671.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220210150834671_0_6556.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220210150834671_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220210150834671_negative_0_5017.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220210150834671_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220210150834671_positive_0_7475.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220210150834671zoom_in_0_8011.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220210150834671zoom_in_0_8011_0_4184.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220210150834671zoom_out_0_2990.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220210150834671zoom_out_0_2990_0_6499.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220214174700691.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220214174700691_0_1863.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220214174700691_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220214174700691_negative_0_8848.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220214174700691_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220214174700691_positive_0_6226.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220214174700691zoom_in_0_7147.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220214174700691zoom_in_0_7147_0_3126.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220214174700691zoom_out_0_8199.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220214174700691zoom_out_0_8199_0_9542.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220218144139637.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220218144139637_0_853.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220218144139637_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220218144139637_negative_0_7227.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220218144139637_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220218144139637_positive_0_984.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220218144139637zoom_in_0_7725.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220218144139637zoom_in_0_7725_0_3814.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220218144139637zoom_out_0_2671.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22Under\\20220218144139637zoom_out_0_2671_0_6050.jpg', shape=(), dtype=string)

# %%
list_ds = tf.data.Dataset.list_files(str(data_ds+'*/*'), shuffle=False)
list_ds = list_ds.shuffle(image_count, reshuffle_each_iteration=False)

for f in list_ds.take(5):
  print(f.numpy())
# Out:
# b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201014090537993zoom_in_0_7660.jpg'
# b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201127151603974zoom_in_0_5409.jpg'
# b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201014090537993zoom_out_0_2889_0_2496.jpg'
# b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20201016160206586_0_5399.jpg'
# b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Training-Test-Super-Resolution-Data\\22OrOver\\20200918150056444_negative_0_7231.jpg'

# %% [markdown]
# A estrutura em árvore dos arquivos pode ser usada para compilar uma lista class_names .

# %%
# class_names = np.array(sorted([item.name for item in data_dir.glob('*') if item.name != "raw_dataframe_no_name.pkl"]))
class_names = np.array(['22OrOver', '22Under'])
print(class_names)
# Out:
# ['22OrOver' '22Under']

# %% [markdown]
# Divida o conjunto de dados em conjuntos de treinamento e validação:

# %%
val_size = int(image_count * 0.2)
train_ds = list_ds.skip(val_size)
val_ds = list_ds.take(val_size)

# %% [markdown]
# Número de imagens em cada conjunto

# %%
print(tf.data.experimental.cardinality(train_ds).numpy())
print(tf.data.experimental.cardinality(val_ds).numpy())
# Out:
# 716
# 14

# %%
val_ds
# Out:
# <TakeDataset element_spec=TensorSpec(shape=(), dtype=tf.string, name=None)>

# %% [markdown]
# Função que converte um caminho de arquivo em um par (img, label) :

# %%
def get_label(file_path):
  # Convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  one_hot = parts[-2] == class_names
  # Integer encode the label
  return tf.argmax(one_hot)

def decode_img(img):
  # Convert the compressed string to a 3D uint8 tensor
  img = tf.io.decode_jpeg(img, channels=3)
  # Resize the image to the desired size
  return tf.image.resize(img, [img_height, img_width])

def process_path(file_path):
  label = get_label(file_path)
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %% [markdown]
# Alguns parâmetros

# %%
batch_size = 4
img_height = 224
img_width = 224

# %% [markdown]
# Use Dataset.map para criar um conjunto de dados de image, label :

# %%
AUTOTUNE = tf.data.AUTOTUNE
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
train_ds = train_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(5):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (224, 224, 3)
# Label:  0
# Image shape:  (224, 224, 3)
# Label:  0
# Image shape:  (224, 224, 3)
# Label:  0
# Image shape:  (224, 224, 3)
# Label:  0
# Image shape:  (224, 224, 3)
# Label:  0

# %% [markdown]
# Configurar conjunto de dados para desempenho Para treinar um modelo com esse conjunto de dados, você precisará dos dados:
#
# Para ser bem embaralhado. A ser em lote. Lotes a serem disponibilizados o mais rápido possível. Esses recursos podem ser adicionados usando a API tf.data . Para obter mais detalhes, visite o guia Desempenho do pipeline de entrada .

# %%
def configure_for_performance(ds):
  ds = ds.cache()
  ds = ds.shuffle(buffer_size=1000)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

train_ds = configure_for_performance(train_ds)
val_ds = configure_for_performance(val_ds)

# %% [markdown]
# Visualize os dados

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(2):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# Treinando o modelo.
#
# Você construiu manualmente um tf.data.Dataset semelhante ao criado por tf.keras.utils.image_dataset_from_directory acima. Você pode continuar treinando o modelo com ele. Como antes, você treinará por apenas algumas épocas para manter o tempo de execução curto.
#
# Para completar, você mostrará como treinar um modelo simples usando os conjuntos de dados que acabou de preparar.
#
# O modelo Sequencial consiste em três blocos de convolução ( tf.keras.layers.Conv2D ) com uma camada de agrupamento máximo ( tf.keras.layers.MaxPooling2D ) em cada um deles. Há uma camada totalmente conectada ( tf.keras.layers.Dense ) com 128 unidades em cima dela que é ativada por uma função de ativação ReLU ( 'relu' ). Este modelo não foi ajustado de forma alguma - o objetivo é mostrar a mecânica usando os conjuntos de dados que você acabou de criar. Para saber mais sobre classificação de imagens, visite o tutorial Classificação de imagens.

# %%
num_classes = 2

#VGG16
model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(64, 3, activation='relu'),
  tf.keras.layers.Conv2D(64, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),

  tf.keras.layers.Conv2D(128, 3, activation='relu'),
  tf.keras.layers.Conv2D(128, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),

  tf.keras.layers.Conv2D(256, 3, activation='relu'),
  tf.keras.layers.Conv2D(256, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),

  tf.keras.layers.Conv2D(512, 3, activation='relu'),
  tf.keras.layers.Conv2D(512, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),

  tf.keras.layers.Conv2D(512, 3, activation='relu'),
  tf.keras.layers.Conv2D(512, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),

  tf.keras.layers.GlobalAveragePooling2D(),
  tf.keras.layers.Dense(1024, activation='relu'),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(1)
])

# %%
model.compile(
  optimizer='adam',
  loss=tf.losses.BinaryCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
epochs=5
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/5
# 179/179 [==============================] - 249s 1s/step - loss: 0.6938 - accuracy: 0.4972 - val_loss: 0.6988 - val_accuracy: 1.0000
# Epoch 2/5
# 179/179 [==============================] - 256s 1s/step - loss: 0.6933 - accuracy: 0.4972 - val_loss: 0.6976 - val_accuracy: 1.0000
# Epoch 3/5
# 179/179 [==============================] - 240s 1s/step - loss: 0.6935 - accuracy: 0.4972 - val_loss: 0.6948 - val_accuracy: 1.0000
# Epoch 4/5
# 179/179 [==============================] - 238s 1s/step - loss: 0.6935 - accuracy: 0.4972 - val_loss: 0.7055 - val_accuracy: 1.0000
# Epoch 5/5
# 179/179 [==============================] - 241s 1s/step - loss: 0.6935 - accuracy: 0.4972 - val_loss: 0.6994 - val_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 222, 222, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 64)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 108, 108, 128)     73856
#
#  conv2d_3 (Conv2D)           (None, 106, 106, 128)     147584
#
#  max_pooling2d_1 (MaxPooling  (None, 53, 53, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 51, 51, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 49, 49, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 24, 24, 256)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 22, 22, 512)       1180160
#
#  conv2d_7 (Conv2D)           (None, 20, 20, 512)       2359808
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 512)      0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 512)         2359808
#
#  conv2d_9 (Conv2D)           (None, 6, 6, 512)         2359808
#
#  max_pooling2d_4 (MaxPooling  (None, 3, 3, 512)        0
#  2D)
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dense_1 (Dense)             (None, 128)               131200
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 10,061,633
# Trainable params: 10,061,633
# Non-trainable params: 0
# _________________________________________________________________

# %%
IMG_SHAPE = (224,224,3)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

# %%
base_model.trainable = False
modelMobileNET = Sequential(
    [
        base_model,
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(1024, activation="relu"),
        tf.keras.layers.Dense(128, activation="relu"),
        tf.keras.layers.Dense(1),
    ]
)

# %%
base_learning_rate = 0.0001
modelMobileNET.compile(optimizer='Adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs=10

history =  modelMobileNET.fit(
    train_ds,
  validation_data=val_ds,
  epochs=epochs
  )
# Out:
# Epoch 1/10
# 179/179 [==============================] - 18s 91ms/step - loss: 0.7699 - accuracy: 0.5209 - val_loss: 0.6897 - val_accuracy: 0.9286
# Epoch 2/10
# 179/179 [==============================] - 16s 92ms/step - loss: 0.6670 - accuracy: 0.5601 - val_loss: 1.0879 - val_accuracy: 0.3571
# Epoch 3/10
# 179/179 [==============================] - 16s 91ms/step - loss: 0.6679 - accuracy: 0.5880 - val_loss: 0.7912 - val_accuracy: 0.7143
# Epoch 4/10
# 179/179 [==============================] - 16s 88ms/step - loss: 0.6508 - accuracy: 0.5992 - val_loss: 0.4909 - val_accuracy: 0.8571
# Epoch 5/10
# 179/179 [==============================] - 16s 87ms/step - loss: 0.6258 - accuracy: 0.6215 - val_loss: 0.9544 - val_accuracy: 0.6429
# Epoch 6/10
# 179/179 [==============================] - 18s 101ms/step - loss: 0.6013 - accuracy: 0.6439 - val_loss: 0.4829 - val_accuracy: 1.0000
# Epoch 7/10
# 179/179 [==============================] - 17s 97ms/step - loss: 0.5347 - accuracy: 0.7137 - val_loss: 0.5414 - val_accuracy: 0.9286
# Epoch 8/10
# 179/179 [==============================] - 17s 95ms/step - loss: 0.5333 - accuracy: 0.7109 - val_loss: 0.5166 - val_accuracy: 0.9286
# Epoch 9/10
# 179/179 [==============================] - 21s 116ms/step - loss: 0.5362 - accuracy: 0.6955 - val_loss: 0.1320 - val_accuracy: 1.0000
# Epoch 10/10
# 179/179 [==============================] - 15s 86ms/step - loss: 0.5077 - accuracy: 0.7402 - val_loss: 0.7649 - val_accuracy: 0.7857

# %%
class_weight = {0: 1.,
                1: 4.}

# %% [markdown]
# Visualize os resultados do treinamento
#
# Crie gráficos de perda e precisão nos conjuntos de treinamento e validação:

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Os gráficos mostram que a precisão do treinamento e a precisão da validação estão com grandes margens, e o modelo alcançou apenas cerca de 60% de precisão no conjunto de validação.
#
# Vamos inspecionar o que deu errado e tentar aumentar o desempenho geral do modelo.

# %% [markdown]
# Aumento de dados
# O overfitting geralmente ocorre quando há um pequeno número de exemplos de treinamento. O aumento de dados adota a abordagem de gerar dados de treinamento adicionais de seus exemplos existentes, aumentando-os usando transformações aleatórias que produzem imagens de aparência crível. Isso ajuda a expor o modelo a mais aspectos dos dados e a generalizar melhor.
#
# Você implementará o aumento de dados usando as seguintes camadas de pré-processamento Keras: tf.keras.layers.RandomFlip , tf.keras.layers.RandomRotation e tf.keras.layers.RandomZoom . Eles podem ser incluídos dentro do seu modelo como outras camadas e executados na GPU.

# %%
data_augmentation = keras.Sequential(
  [
    #layers.RandomFlip("horizontal",input_shape=(img_height,img_width,3)),
    #layers.RandomRotation(0.1),
    #layers.RandomZoom(0.1),
  ]
)

# %% [markdown]
# Vamos visualizar alguns exemplos aumentados aplicando o aumento de dados à mesma imagem várias vezes:

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# Dropout
#
# Outra técnica para reduzir o overfitting é introduzir a regularização de dropout na rede.
#
# Quando você aplica dropout a uma camada, ela descarta aleatoriamente (definindo a ativação como zero) um número de unidades de saída da camada durante o processo de treinamento. Dropout recebe um número fracionário como valor de entrada, na forma de 0,1, 0,2, 0,4, etc. Isso significa descartar 10%, 20% ou 40% das unidades de saída aleatoriamente da camada aplicada.
#
# Vamos criar uma nova rede neural com tf.keras.layers.Dropout antes de treiná-la usando as imagens aumentadas:

# %%
model = Sequential([
  #data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs = 10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 179/179 [==============================] - 22s 121ms/step - loss: 0.7530 - accuracy: 0.4986 - val_loss: 0.6918 - val_accuracy: 0.7143
# Epoch 2/10
# 179/179 [==============================] - 21s 117ms/step - loss: 0.6946 - accuracy: 0.5321 - val_loss: 0.3290 - val_accuracy: 1.0000
# Epoch 3/10
# 179/179 [==============================] - 23s 127ms/step - loss: 0.6689 - accuracy: 0.5992 - val_loss: 0.7213 - val_accuracy: 0.4286
# Epoch 4/10
# 179/179 [==============================] - 22s 123ms/step - loss: 0.6058 - accuracy: 0.6885 - val_loss: 0.6108 - val_accuracy: 0.7857
# Epoch 5/10
# 179/179 [==============================] - 22s 122ms/step - loss: 0.5048 - accuracy: 0.7570 - val_loss: 0.6116 - val_accuracy: 0.7143
# Epoch 6/10
# 179/179 [==============================] - 22s 123ms/step - loss: 0.3917 - accuracy: 0.8142 - val_loss: 1.0427 - val_accuracy: 0.4286
# Epoch 7/10
# 179/179 [==============================] - 22s 121ms/step - loss: 0.2933 - accuracy: 0.8715 - val_loss: 1.6103 - val_accuracy: 0.5000
# Epoch 8/10
# 179/179 [==============================] - 22s 123ms/step - loss: 0.1748 - accuracy: 0.9302 - val_loss: 3.2399 - val_accuracy: 0.4286
# Epoch 9/10
# 179/179 [==============================] - 22s 122ms/step - loss: 0.1257 - accuracy: 0.9497 - val_loss: 3.2445 - val_accuracy: 0.4286
# Epoch 10/10
# 179/179 [==============================] - 23s 128ms/step - loss: 0.0884 - accuracy: 0.9693 - val_loss: 2.9673 - val_accuracy: 0.7143

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 224, 224, 3)       0
#
#  conv2d_10 (Conv2D)          (None, 224, 224, 16)      448
#
#  max_pooling2d_5 (MaxPooling  (None, 112, 112, 16)     0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 112, 112, 32)      4640
#
#  max_pooling2d_6 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 56, 56, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 28, 28, 64)        0
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense_6 (Dense)             (None, 128)               6422656
#
#  dense_7 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 6,446,498
# Trainable params: 6,446,498
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Visualize os resultados do treinamento
# Depois de aplicar o aumento de dados e tf.keras.layers.Dropout , há menos overfitting do que antes, e a precisão do treinamento e da validação está mais alinhada:

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
from skimage import io, color

# 22Under test
# filename = cwd + "/data/22Under/20210309142219315.jpg"
# filename = cwd + "/data/22Under/20220111101736079.jpg"
# filename = cwd + "/DataAugmentation/Original/22Under/20201023151105049.jpg"
filename = cwd + "/DataAugmentation/Original/22Under/20210421162806019.jpg"
# filename = cwd + "/data/22Under/20211130152241580.jpg"
# filename = cwd + "/data/22Under/20220124142821672.jpg"
# filename = cwd + "/data/22Under/20210326150602233.jpg"

# 22OrOver test
# filename = cwd + "/data/22OrOver/20201014090537993.jpg"
# filename = cwd + "/data/22OrOver/20220223151246666.jpg"
# filename = cwd + "/data/22OrOver/20210427150827826.jpg"
# filename = cwd + "/DataAugmentation/Original/22OrOver/20201014090537993.jpg"
# filename = cwd + "/DataAugmentation/Original/22OrOver/20201016160206586.jpg"
# filename = cwd + "/data/22OrOver/20220224163251336.jpg"

img = io.imread(filename)
img = color.gray2rgb(img)

# %% [markdown]
# Prever novos dados
# Por fim, vamos usar nosso modelo para classificar uma imagem que não foi incluída nos conjuntos de treinamento ou validação.
#
# Nota: As camadas de aumento e eliminação de dados estão inativas no momento da inferência.

# %%
img = tf.keras.utils.load_img(
    filename, target_size=(img_height, img_width)
)

img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 87ms/step
# This image most likely belongs to 22Under with a 77.19 percent confidence.

# %% [markdown]
# Com transfer learning
#
# https://medium.com/analytics-vidhya/face-recognition-using-transfer-learning-and-vgg16-cf4de57b9154
