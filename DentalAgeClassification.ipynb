# %% [markdown]
# ### Classificação binária de idade utilizado radiografias panorâmicas da arcada dentária

# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
#import tensorflow_datasets as tfds

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import os
cwd = os.getcwd()

# Shows Current Working Directory
print(cwd)

print(tf.__version__)
# Out:
# C:\Users\lucas\Desktop\PDI - Git\PDI_Dental_Age_Classification
# 2.9.1

# %% [markdown]
# Dental22
#   22Under/
#   22OrOver/

# %%
import pathlib

data_dir = cwd + '/data'
data_dir = pathlib.Path(data_dir)
print(data_dir)
# Out:
# C:\Users\lucas\Desktop\PDI - Git\PDI_Dental_Age_Classification\data

# %% [markdown]
# Total de imagens:

# %%
image_count = len(list(data_dir.glob('*.jpg')))
print(image_count)
# Out:
# 73

# %% [markdown]
# Cada diretório contém imagens de pacientes abaixo de 22 anos ou de 22 anos acima.

# %%
under22 = list(data_dir.glob('22Under/*'))
PIL.Image.open(str(under22[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1581x720 at 0x1CE2B729610>

# %%
data_ds = cwd + '\\Traing-Test-Normal-Data/'

# %%
aux_list = tf.data.Dataset.list_files(str(data_ds+'*/*'), shuffle=False)
aux_list.shape()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23484/772899980.py in <module>
#       1 aux_list = tf.data.Dataset.list_files(str(data_ds+'*/*'), shuffle=False)
# ----> 2 aux_list.shape()
#
# AttributeError: 'TensorSliceDataset' object has no attribute 'shape'

# %%
for i in aux_list:
    print(i)
# Out:
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20200918150056444.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20200918150056444_0_5185.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20200918150056444_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20200918150056444_negative_0_1171.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20200918150056444_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20200918150056444_positive_0_2625.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20200918150056444zoom_in_0_950.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20200918150056444zoom_in_0_950_0_6393.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20200918150056444zoom_out_0_5257.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20200918150056444zoom_out_0_5257_0_3685.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201014090537993.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201014090537993_0_3588.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201014090537993_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201014090537993_negative_0_3076.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201014090537993_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201014090537993_positive_0_2401.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201014090537993zoom_in_0_7228.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201014090537993zoom_in_0_7228_0_2787.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201014090537993zoom_out_0_5428.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201014090537993zoom_out_0_5428_0_4373.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201016160206586.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201016160206586_0_4048.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201016160206586_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201016160206586_negative_0_4829.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201016160206586_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201016160206586_positive_0_3813.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201016160206586zoom_in_0_6934.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201016160206586zoom_in_0_6934_0_1270.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201016160206586zoom_out_0_9349.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201016160206586zoom_out_0_9349_0_8907.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201127151603974.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201127151603974_0_8802.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201127151603974_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201127151603974_negative_0_5277.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201127151603974_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201127151603974_positive_0_3287.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201127151603974zoom_in_0_8792.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201127151603974zoom_in_0_8792_0_8417.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201127151603974zoom_out_0_1813.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201127151603974zoom_out_0_1813_0_9325.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201215150320498.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201215150320498_0_8406.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201215150320498_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201215150320498_negative_0_4079.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201215150320498_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201215150320498_positive_0_8452.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201215150320498zoom_in_0_7353.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201215150320498zoom_in_0_7353_0_1038.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201215150320498zoom_out_0_5639.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201215150320498zoom_out_0_5639_0_1269.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201217150805586.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201217150805586_0_9227.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201217150805586_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201217150805586_negative_0_4448.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201217150805586_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201217150805586_positive_0_7111.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201217150805586zoom_in_0_1889.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201217150805586zoom_in_0_1889_0_1926.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201217150805586zoom_out_0_3038.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201217150805586zoom_out_0_3038_0_4721.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20210108164409410.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20210108164409410_0_8186.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20210108164409410_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20210108164409410_negative_0_3847.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20210108164409410_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20210108164409410_positive_0_1731.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20210108164409410zoom_in_0_5853.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20
jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220111164240187zoom_in_0_7700.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220111164240187zoom_in_0_7700_0_9516.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220111164240187zoom_out_0_3627.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220111164240187zoom_out_0_3627_0_5478.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220111182556416.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220111182556416_0_1980.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220111182556416_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220111182556416_negative_0_4648.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220111182556416_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220111182556416_positive_0_3428.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220111182556416zoom_in_0_7251.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220111182556416zoom_in_0_7251_0_3741.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220111182556416zoom_out_0_1941.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220111182556416zoom_out_0_1941_0_154.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220124142821672.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220124142821672_0_1343.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220124142821672_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220124142821672_negative_0_8838.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220124142821672_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220124142821672_positive_0_5686.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220124142821672zoom_in_0_8870.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220124142821672zoom_in_0_8870_0_1179.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220124142821672zoom_out_0_1908.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220124142821672zoom_out_0_1908_0_1133.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220128121500407.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220128121500407_0_1071.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220128121500407_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220128121500407_negative_0_6171.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220128121500407_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220128121500407_positive_0_7621.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220128121500407zoom_in_0_9826.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220128121500407zoom_in_0_9826_0_4241.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220128121500407zoom_out_0_1769.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220128121500407zoom_out_0_1769_0_5080.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220209164953264.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220209164953264_0_3142.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220209164953264_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220209164953264_negative_0_618.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220209164953264_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220209164953264_positive_0_5225.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220209164953264zoom_in_0_1069.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220209164953264zoom_in_0_1069_0_5891.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220209164953264zoom_out_0_4798.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220209164953264zoom_out_0_4798_0_3482.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220210150834671.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220210150834671_0_1212.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220210150834671_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220210150834671_negative_0_4535.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220210150834671_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220210150834671_positive_0_485.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220210150834671zoom_in_0_1688.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220210150834671zoom_in_0_1688_0_1524.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220210150834671zoom_out_0_5757.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220210150834671zoom_out_0_5757_0_3676.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220214174700691.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220214174700691_0_3724.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220214174700691_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220214174700691_negative_0_4004.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220214174700691_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220214174700691_positive_0_5091.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220214174700691zoom_in_0_8787.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220214174700691zoom_in_0_8787_0_779.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220214174700691zoom_out_0_3319.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220214174700691zoom_out_0_3319_0_3956.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220218144139637.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220218144139637_0_8046.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220218144139637_negative.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220218144139637_negative_0_8145.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220218144139637_positive.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220218144139637_positive_0_2012.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220218144139637zoom_in_0_3142.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220218144139637zoom_in_0_3142_0_3599.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220218144139637zoom_out_0_1286.jpg', shape=(), dtype=string)
# tf.Tensor(b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22Under\\20220218144139637zoom_out_0_1286_0_9853.jpg', shape=(), dtype=string)

# %%
list_ds = tf.data.Dataset.list_files(str(data_ds+'*/*'), shuffle=False)
list_ds = list_ds.shuffle(image_count, reshuffle_each_iteration=False)

for f in list_ds.take(5):
  print(f.numpy())
# Out:
# b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20210108164409410zoom_in_0_5853.jpg'
# b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201217150805586zoom_in_0_1889.jpg'
# b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201014090537993zoom_out_0_5428_0_4373.jpg'
# b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201217150805586zoom_out_0_3038_0_4721.jpg'
# b'C:\\Users\\lucas\\Desktop\\PDI - Git\\PDI_Dental_Age_Classification\\Traing-Test-Normal-Data\\22OrOver\\20201014090537993_negative.jpg'

# %% [markdown]
# A estrutura em árvore dos arquivos pode ser usada para compilar uma lista class_names .

# %%
# class_names = np.array(sorted([item.name for item in data_dir.glob('*') if item.name != "raw_dataframe_no_name.pkl"]))
class_names = np.array(['22OrOver', '22Under'])
print(class_names)
# Out:
# ['22OrOver' '22Under']

# %% [markdown]
# Divida o conjunto de dados em conjuntos de treinamento e validação:

# %%
val_size = int(image_count * 0.2)
train_ds = list_ds.skip(val_size)
val_ds = list_ds.take(val_size)

# %% [markdown]
# Número de imagens em cada conjunto

# %%
print(tf.data.experimental.cardinality(train_ds).numpy())
print(tf.data.experimental.cardinality(val_ds).numpy())
# Out:
# 716
# 14

# %%
val_ds
# Out:
# <TakeDataset element_spec=TensorSpec(shape=(), dtype=tf.string, name=None)>

# %% [markdown]
# Função que converte um caminho de arquivo em um par (img, label) :

# %%
def get_label(file_path):
  # Convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  one_hot = parts[-2] == class_names
  # Integer encode the label
  return tf.argmax(one_hot)

def decode_img(img):
  # Convert the compressed string to a 3D uint8 tensor
  img = tf.io.decode_jpeg(img, channels=3)
  # Resize the image to the desired size
  return tf.image.resize(img, [img_height, img_width])

def process_path(file_path):
  label = get_label(file_path)
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %% [markdown]
# Alguns parâmetros

# %%
batch_size = 4
img_height = 224
img_width = 224

# %% [markdown]
# Use Dataset.map para criar um conjunto de dados de image, label :

# %%
AUTOTUNE = tf.data.AUTOTUNE
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
train_ds = train_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(5):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (224, 224, 3)
# Label:  0
# Image shape:  (224, 224, 3)
# Label:  0
# Image shape:  (224, 224, 3)
# Label:  0
# Image shape:  (224, 224, 3)
# Label:  0
# Image shape:  (224, 224, 3)
# Label:  0

# %% [markdown]
# Configurar conjunto de dados para desempenho Para treinar um modelo com esse conjunto de dados, você precisará dos dados:
#
# Para ser bem embaralhado. A ser em lote. Lotes a serem disponibilizados o mais rápido possível. Esses recursos podem ser adicionados usando a API tf.data . Para obter mais detalhes, visite o guia Desempenho do pipeline de entrada .

# %%
def configure_for_performance(ds):
  ds = ds.cache()
  ds = ds.shuffle(buffer_size=1000)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

train_ds = configure_for_performance(train_ds)
val_ds = configure_for_performance(val_ds)

# %% [markdown]
# Visualize os dados

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(2):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# Treinando o modelo.
#
# Você construiu manualmente um tf.data.Dataset semelhante ao criado por tf.keras.utils.image_dataset_from_directory acima. Você pode continuar treinando o modelo com ele. Como antes, você treinará por apenas algumas épocas para manter o tempo de execução curto.
#
# Para completar, você mostrará como treinar um modelo simples usando os conjuntos de dados que acabou de preparar.
#
# O modelo Sequencial consiste em três blocos de convolução ( tf.keras.layers.Conv2D ) com uma camada de agrupamento máximo ( tf.keras.layers.MaxPooling2D ) em cada um deles. Há uma camada totalmente conectada ( tf.keras.layers.Dense ) com 128 unidades em cima dela que é ativada por uma função de ativação ReLU ( 'relu' ). Este modelo não foi ajustado de forma alguma - o objetivo é mostrar a mecânica usando os conjuntos de dados que você acabou de criar. Para saber mais sobre classificação de imagens, visite o tutorial Classificação de imagens.

# %%
num_classes = 2

#VGG16
model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(64, 3, activation='relu'),
  tf.keras.layers.Conv2D(64, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),

  tf.keras.layers.Conv2D(128, 3, activation='relu'),
  tf.keras.layers.Conv2D(128, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),

  tf.keras.layers.Conv2D(256, 3, activation='relu'),
  tf.keras.layers.Conv2D(256, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),

  tf.keras.layers.Conv2D(512, 3, activation='relu'),
  tf.keras.layers.Conv2D(512, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),

  tf.keras.layers.Conv2D(512, 3, activation='relu'),
  tf.keras.layers.Conv2D(512, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),

  tf.keras.layers.GlobalAveragePooling2D(),
  tf.keras.layers.Dense(1024, activation='relu'),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(1)
])

# %%
model.compile(
  optimizer='adam',
  loss=tf.losses.BinaryCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
epochs=5
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/5
# 179/179 [==============================] - 259s 1s/step - loss: 0.6941 - accuracy: 0.4972 - val_loss: 0.6690 - val_accuracy: 1.0000
# Epoch 2/5
# 179/179 [==============================] - 265s 1s/step - loss: 0.6937 - accuracy: 0.4972 - val_loss: 0.7034 - val_accuracy: 1.0000
# Epoch 3/5
# 179/179 [==============================] - 234s 1s/step - loss: 0.6934 - accuracy: 0.4972 - val_loss: 0.6982 - val_accuracy: 1.0000
# Epoch 4/5
# 179/179 [==============================] - 234s 1s/step - loss: 0.6933 - accuracy: 0.4972 - val_loss: 0.6985 - val_accuracy: 1.0000
# Epoch 5/5
# 179/179 [==============================] - 237s 1s/step - loss: 0.6933 - accuracy: 0.4972 - val_loss: 0.6995 - val_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 222, 222, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 64)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 108, 108, 128)     73856
#
#  conv2d_3 (Conv2D)           (None, 106, 106, 128)     147584
#
#  max_pooling2d_1 (MaxPooling  (None, 53, 53, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 51, 51, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 49, 49, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 24, 24, 256)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 22, 22, 512)       1180160
#
#  conv2d_7 (Conv2D)           (None, 20, 20, 512)       2359808
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 512)      0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 512)         2359808
#
#  conv2d_9 (Conv2D)           (None, 6, 6, 512)         2359808
#
#  max_pooling2d_4 (MaxPooling  (None, 3, 3, 512)        0
#  2D)
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dense_1 (Dense)             (None, 128)               131200
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 10,061,633
# Trainable params: 10,061,633
# Non-trainable params: 0
# _________________________________________________________________

# %%
IMG_SHAPE = (224,224,3)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 1s 0us/step

# %%
base_model.trainable = False
modelMobileNET = Sequential(
    [
        base_model,
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(1024, activation="relu"),
        tf.keras.layers.Dense(128, activation="relu"),
        tf.keras.layers.Dense(1),
    ]
)

# %%
base_learning_rate = 0.0001
modelMobileNET.compile(optimizer='Adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs=10

history =  modelMobileNET.fit(
    train_ds,
  validation_data=val_ds,
  epochs=epochs
  )
# Out:
# Epoch 1/10
# 179/179 [==============================] - 18s 91ms/step - loss: 0.8192 - accuracy: 0.5545 - val_loss: 0.6577 - val_accuracy: 0.7143
# Epoch 2/10
# 179/179 [==============================] - 16s 88ms/step - loss: 0.6559 - accuracy: 0.5964 - val_loss: 0.5499 - val_accuracy: 1.0000
# Epoch 3/10
# 179/179 [==============================] - 16s 88ms/step - loss: 0.6222 - accuracy: 0.6243 - val_loss: 0.3762 - val_accuracy: 1.0000
# Epoch 4/10
# 179/179 [==============================] - 16s 88ms/step - loss: 0.5554 - accuracy: 0.6788 - val_loss: 0.5926 - val_accuracy: 0.7857
# Epoch 5/10
# 179/179 [==============================] - 16s 88ms/step - loss: 0.5328 - accuracy: 0.6997 - val_loss: 1.1359 - val_accuracy: 0.5000
# Epoch 6/10
# 179/179 [==============================] - 16s 88ms/step - loss: 0.5171 - accuracy: 0.7025 - val_loss: 0.4628 - val_accuracy: 1.0000
# Epoch 7/10
# 179/179 [==============================] - 16s 87ms/step - loss: 0.4965 - accuracy: 0.7318 - val_loss: 0.8660 - val_accuracy: 0.5714
# Epoch 8/10
# 179/179 [==============================] - 19s 104ms/step - loss: 0.4878 - accuracy: 0.7346 - val_loss: 0.5062 - val_accuracy: 0.8571
# Epoch 9/10
# 179/179 [==============================] - 16s 91ms/step - loss: 0.4638 - accuracy: 0.7570 - val_loss: 0.5092 - val_accuracy: 0.8571
# Epoch 10/10
# 179/179 [==============================] - 16s 87ms/step - loss: 0.4566 - accuracy: 0.7640 - val_loss: 0.3209 - val_accuracy: 0.9286

# %%
class_weight = {0: 1.,
                1: 4.}

# %% [markdown]
# Visualize os resultados do treinamento
#
# Crie gráficos de perda e precisão nos conjuntos de treinamento e validação:

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Os gráficos mostram que a precisão do treinamento e a precisão da validação estão com grandes margens, e o modelo alcançou apenas cerca de 60% de precisão no conjunto de validação.
#
# Vamos inspecionar o que deu errado e tentar aumentar o desempenho geral do modelo.

# %% [markdown]
# Aumento de dados
# O overfitting geralmente ocorre quando há um pequeno número de exemplos de treinamento. O aumento de dados adota a abordagem de gerar dados de treinamento adicionais de seus exemplos existentes, aumentando-os usando transformações aleatórias que produzem imagens de aparência crível. Isso ajuda a expor o modelo a mais aspectos dos dados e a generalizar melhor.
#
# Você implementará o aumento de dados usando as seguintes camadas de pré-processamento Keras: tf.keras.layers.RandomFlip , tf.keras.layers.RandomRotation e tf.keras.layers.RandomZoom . Eles podem ser incluídos dentro do seu modelo como outras camadas e executados na GPU.

# %%
data_augmentation = keras.Sequential(
  [
    #layers.RandomFlip("horizontal",input_shape=(img_height,img_width,3)),
    #layers.RandomRotation(0.1),
    #layers.RandomZoom(0.1),
  ]
)

# %% [markdown]
# Vamos visualizar alguns exemplos aumentados aplicando o aumento de dados à mesma imagem várias vezes:

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# Dropout
#
# Outra técnica para reduzir o overfitting é introduzir a regularização de dropout na rede.
#
# Quando você aplica dropout a uma camada, ela descarta aleatoriamente (definindo a ativação como zero) um número de unidades de saída da camada durante o processo de treinamento. Dropout recebe um número fracionário como valor de entrada, na forma de 0,1, 0,2, 0,4, etc. Isso significa descartar 10%, 20% ou 40% das unidades de saída aleatoriamente da camada aplicada.
#
# Vamos criar uma nova rede neural com tf.keras.layers.Dropout antes de treiná-la usando as imagens aumentadas:

# %%
model = Sequential([
  #data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs = 10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 179/179 [==============================] - 22s 119ms/step - loss: 0.7122 - accuracy: 0.4916 - val_loss: 0.6536 - val_accuracy: 1.0000
# Epoch 2/10
# 179/179 [==============================] - 25s 140ms/step - loss: 0.6895 - accuracy: 0.5391 - val_loss: 0.6203 - val_accuracy: 0.4286
# Epoch 3/10
# 179/179 [==============================] - 22s 125ms/step - loss: 0.6490 - accuracy: 0.6103 - val_loss: 0.6485 - val_accuracy: 0.5714
# Epoch 4/10
# 179/179 [==============================] - 24s 131ms/step - loss: 0.5652 - accuracy: 0.6690 - val_loss: 0.8296 - val_accuracy: 0.3571
# Epoch 5/10
# 179/179 [==============================] - 23s 129ms/step - loss: 0.4392 - accuracy: 0.7514 - val_loss: 1.1691 - val_accuracy: 0.4286
# Epoch 6/10
# 179/179 [==============================] - 22s 122ms/step - loss: 0.3712 - accuracy: 0.8128 - val_loss: 1.0017 - val_accuracy: 0.5714
# Epoch 7/10
# 179/179 [==============================] - 25s 142ms/step - loss: 0.2821 - accuracy: 0.8617 - val_loss: 3.6753 - val_accuracy: 0.2857
# Epoch 8/10
# 179/179 [==============================] - 24s 136ms/step - loss: 0.2135 - accuracy: 0.9106 - val_loss: 2.2589 - val_accuracy: 0.5714
# Epoch 9/10
# 179/179 [==============================] - 23s 127ms/step - loss: 0.1725 - accuracy: 0.9260 - val_loss: 3.2032 - val_accuracy: 0.5714
# Epoch 10/10
# 179/179 [==============================] - 22s 121ms/step - loss: 0.1116 - accuracy: 0.9637 - val_loss: 3.5326 - val_accuracy: 0.4286

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 224, 224, 3)       0
#
#  conv2d_10 (Conv2D)          (None, 224, 224, 16)      448
#
#  max_pooling2d_5 (MaxPooling  (None, 112, 112, 16)     0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 112, 112, 32)      4640
#
#  max_pooling2d_6 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 56, 56, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 28, 28, 64)        0
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense_6 (Dense)             (None, 128)               6422656
#
#  dense_7 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 6,446,498
# Trainable params: 6,446,498
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Visualize os resultados do treinamento
# Depois de aplicar o aumento de dados e tf.keras.layers.Dropout , há menos overfitting do que antes, e a precisão do treinamento e da validação está mais alinhada:

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
from skimage import io, color

# 22Under test
# filename = cwd + "/data/22Under/20210309142219315.jpg"
# filename = cwd + "/data/22Under/20220111101736079.jpg"
# filename = cwd + "/DataAugmentation/Original/22Under/20201023151105049.jpg"
filename = cwd + "/DataAugmentation/Original/22Under/20210421162806019.jpg"
# filename = cwd + "/data/22Under/20211130152241580.jpg"
# filename = cwd + "/data/22Under/20220124142821672.jpg"
# filename = cwd + "/data/22Under/20210326150602233.jpg"

# 22OrOver test
# filename = cwd + "/data/22OrOver/20201014090537993.jpg"
# filename = cwd + "/data/22OrOver/20220223151246666.jpg"
# filename = cwd + "/data/22OrOver/20210427150827826.jpg"
# filename = cwd + "/DataAugmentation/Original/22OrOver/20201014090537993.jpg"
# filename = cwd + "/DataAugmentation/Original/22OrOver/20201016160206586.jpg"
# filename = cwd + "/data/22OrOver/20220224163251336.jpg"

img = io.imread(filename)
img = color.gray2rgb(img)

# %% [markdown]
# Prever novos dados
# Por fim, vamos usar nosso modelo para classificar uma imagem que não foi incluída nos conjuntos de treinamento ou validação.
#
# Nota: As camadas de aumento e eliminação de dados estão inativas no momento da inferência.

# %%
img = tf.keras.utils.load_img(
    filename, target_size=(img_height, img_width)
)

img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 88ms/step
# This image most likely belongs to 22Under with a 99.99 percent confidence.

# %% [markdown]
# Com transfer learning
#
# https://medium.com/analytics-vidhya/face-recognition-using-transfer-learning-and-vgg16-cf4de57b9154
